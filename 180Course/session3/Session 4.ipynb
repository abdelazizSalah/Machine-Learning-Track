# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series(data = [1, 2], index = ['one', 'two'], name = 'Numbers', dtype = float)
s
# Out:
# one    1.0
# two    2.0
# Name: Numbers, dtype: float64

# %%
s + 2
# Out:
# one    3.0
# two    4.0
# Name: Numbers, dtype: float64

# %%
np.exp(s)
# Out:
# one    2.718282
# two    7.389056
# Name: Numbers, dtype: float64

# %%
s[s > 1]
# Out:
# two    2.0
# Name: Numbers, dtype: float64

# %%
s
# Out:
# one    1.0
# two    2.0
# Name: Numbers, dtype: float64

# %%
df = pd.DataFrame(data = {'col_1':[1, 2],
                          'col_2':[22,3]}, index = ['one', 'two'])
df
# Out:
#      col_1  col_2
# one      1     22
# two      2      3

# %%
df.col_1
# Out:
# 0    1
# 1    2
# Name: col_1, dtype: int64

# %%
df = pd.read_csv('winemag-data-130k-v2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0  country  \
# 129966      129966  Germany
# 129967      129967       US
# 129968      129968   France
# 129969      129969   France
# 129970      129970   France
#
#                                               description  \
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# 129969  A dry style of Pinot Gris, this is crisp with ...
# 129970  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price province  \
# 129966  Brauneberger Juffer-Sonnenuhr Spätlese      90   28.0    Mosel
# 129967                                     NaN      90   75.0   Oregon
# 129968                                   Kritt      90   30.0   Alsace
# 129969                                     NaN      90   32.0   Alsace
# 129970           Lieu-dit Harth Cuvée Caroline      90   21.0   Alsace
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
df.describe(include = 'all')
# Out:
#            Unnamed: 0 country  \
# count   129971.000000  129908
# unique            NaN      43
# top               NaN      US
# freq              NaN   54504
# mean     64985.000000     NaN
# std      37519.540256     NaN
# min          0.000000     NaN
# 25%      32492.500000     NaN
# 50%      64985.000000     NaN
# 75%      97477.500000     NaN
# max     129970.000000     NaN
#
#                                               description designation  \
# count                                              129971       92506
# unique                                             119955       37979
# top     Cigar box, café au lait, and dried tobacco aro...     Reserve
# freq                                                    3        2009
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# ...

# %%
df['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df.country
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# iloc , loc

# %%
# iloc [row , col]

df.iloc[[1, 2, 3], :]
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
#
#             designation  points  price  province             region_1  \
# 1              Avidagos      87   15.0     Douro                  NaN
# 2                   NaN      87   14.0    Oregon    Willamette Valley
# 3  Reserve Late Harvest      87   13.0  Michigan  Lake Michigan Shore
#
#             region_2         taster_name taster_twitter_handle  \
# 1                NaN          Roger Voss            @vossroger
# 2  Willamette Valley        Paul Gregutt           @paulgwine
# 3                NaN  Alexander Peartree                   NaN
#
#                                                title         variety  \
# ...

# %%
df.loc[0, ['price']]
# Out:
# price    NaN
# Name: 0, dtype: object

# %%
df.loc[ (df['country'] == 'Portugal') & (df['points'] > 90)]
# Out:
#         Unnamed: 0   country  \
# 151            151  Portugal
# 157            157  Portugal
# 473            473  Portugal
# 642            642  Portugal
# 646            646  Portugal
# ...            ...       ...
# 129130      129130  Portugal
# 129671      129671  Portugal
# 129680      129680  Portugal
# 129685      129685  Portugal
# 129901      129901  Portugal
#
#                                               description  \
# 151     This bottling shows a rich, wood-aged wine, fu...
# 157     From an estate in the south of the Alentejo, t...
# 473     A powerful wine, richly structured and full of...
# 642     This is a new wine from the hands of master wi...
# 646     As its name suggests this is a selection of ba...
# ...                                                   ...
# 129130  Bual is the grape that creates the medium-swee...
# 129671  Two classic Dão grapes, Touriga Nacional and T...
# 129680  Old vines in a field blend give a rich structu...
# ...

# %%
df['New_col'] = 0
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
# df.loc[ condition , col_name u want to affect] = value

df.loc[df['points'] > 90, 'New_col'] = 1

# %%
df.loc[df['points'] > 90]
# Out:
#         Unnamed: 0    country  \
# 119            119     France
# 120            120      Italy
# 121            121         US
# 122            122         US
# 123            123  Australia
# ...            ...        ...
# 129936      129936     France
# 129937      129937    Austria
# 129938      129938  Argentina
# 129939      129939    Austria
# 129940      129940         US
#
#                                               description  \
# 119     Medium-gold in color. Complex and inviting nos...
# 120     Slightly backward, particularly given the vint...
# 121     The vineyard is one of the better Chardonnay s...
# 122     Defines Rockpile Zinfandel in intensity of fru...
# 123     The blend is roughly two-thirds Shiraz and one...
# ...                                                   ...
# 129936  A blend from several premier cru vineyards in ...
# 129937  Smooth, creamy aromas are followed by a rich, ...
# 129938  Compared to the regular 2006 Malbec from Chaka...
# ...

# %%
df.rename(columns = {"Country" : "country"}, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.isnull().mean() * 100
# Out:
# Unnamed: 0                0.000000
# country                   0.000000
# description               0.000000
# designation              28.825661
# points                    0.000000
# price                     6.921544
# province                  0.048472
# region_1                 16.347493
# taster_name              20.192197
# taster_twitter_handle    24.015357
# title                     0.000000
# variety                   0.000769
# winery                    0.000000
# New_col                   0.000000
# dtype: float64

# %%
df.drop(columns = ['region_2'], inplace = True)

# %%
# numeric , # categorical
# mean          mode
# mode
# median

# %%
x = pd.Series(data = [1, 1, 1, 1, 2, 3, 4, 5, 4, 6, 6, 6, 6])

x.mode()
# Out:
# 0    1
# 1    6
# dtype: int64

# %%
df['country'].fillna(df['country'].mode()[0], inplace = True)

# %%
df['country'].mode()
# Out:
# 0    US
# dtype: object

# %%
df['country'].unique()
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', 'Turkey', 'Czech Republic', 'Slovenia', 'Luxembourg',
#        'Croatia', 'Georgia', 'Uruguay', 'England', 'Lebanon', 'Serbia',
#        'Brazil', 'Moldova', 'Morocco', 'Peru', 'India', 'Bulgaria',
#        'Cyprus', 'Armenia', 'Switzerland', 'Bosnia and Herzegovina',
#        'Ukraine', 'Slovakia', 'Macedonia', 'China', 'Egypt'], dtype=object)

# %%
df.head()
# Out:
#    Unnamed: 0  country                                        description  \
# 0           0      3.0  Aromas include tropical fruit, broom, brimston...
# 1           1      2.0  This is ripe and fruity, a wine that is smooth...
# 2           2      1.0  Tart and snappy, the flavors of lime flesh and...
# 3           3      1.0  Pineapple rind, lemon pith and orange blossom ...
# 4           4      1.0  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      89    NaN  Sicily & Sardinia
# 1                            Avidagos      89   15.0              Douro
# 2                                 NaN      89   14.0             Oregon
# 3                Reserve Late Harvest      89   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      89   65.0             Oregon
#
#               region_1         taster_name taster_twitter_handle  \
# ...

# %%
df.points = df.points.map(lambda x: x + 1)

# %%
# l = ['a', 'b', 'c']

# for i, v in enumerate(l):
#     print(i, v)
# Out:
# 0 a
# 1 b
# 2 c

# %%
country_mapping = {"US" : 1, "Portugal":2, "Italy":3}
df.country = df.country.map(country_mapping)

# %%
df.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
df.groupby('country').points
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 81814     89
# 83622     90
# 96759     88
# 109989    89
# 110246    84
# Name: points, Length: 202, dtype: int64

# %%
df1 = pd.read_csv('winemag-data-130k-v2.csv')
df2 = pd.read_csv('winemag-data-130k-v2.csv')
df3 = pd.concat([df1,df2])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259942 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             259942 non-null  int64
#  1   country                259816 non-null  object
#  2   description            259942 non-null  object
#  3   designation            185012 non-null  object
#  4   points                 259942 non-null  int64
#  5   price                  241950 non-null  float64
#  6   province               259816 non-null  object
#  7   region_1               217448 non-null  object
#  8   region_2               101022 non-null  object
#  9   taster_name            207454 non-null  object
#  10  taster_twitter_handle  197516 non-null  object
#  11  title                  259942 non-null  object
#  12  variety                259940 non-null  object
#  13  winery                 259942 non-null  object
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   country                129908 non-null  object
#  2   description            129971 non-null  object
#  3   designation            92506 non-null   object
#  4   points                 129971 non-null  int64
#  5   price                  120975 non-null  float64
#  6   province               129908 non-null  object
#  7   region_1               108724 non-null  object
#  8   region_2               50511 non-null   object
#  9   taster_name            103727 non-null  object
#  10  taster_twitter_handle  98758 non-null   object
#  11  title                  129971 non-null  object
#  12  variety                129970 non-null  object
#  13  winery                 129971 non-null  object
# ...

# %%
'''
read_csv
describe
info
iloc
loc
sort_values
isnull
fillna
drop
groupby
rename
to_csv
dropna
'''
# Out:
# '\nread_csv\ndescribe\ninfo\niloc\nloc\nsort_values\nisnull\nfillna\ndrop\ngroupby\nrename\nto_csv\ndropna\n'

# %%
df3.to_csv('new_data.csv')
